# %% [markdown]
# ![certi.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Enlace Linkedin

# %% [markdown]
# https://www.coursera.org/account/accomplishments/verify/MHGSVY86QC3P

# %% [markdown]
# ![link.JPG](data:image/jpeg;base64,...)
